# %% [markdown]
# ### This is the notebook of pandas and excel

# %%
str="Hello"

# %%
str.replace('o','a')

# %%
m1 = 'Im learning Pandas with excel,'
m2 = ' and it is fun!!'
m3 = m1 + m2

# %%
f'Hello world... {m3}'

# %% [markdown]
# ### Lists

# %%
countries = ['Rusia','India','Brazil','China','South America']
countries

# %%
countries.append('Canada')
countries.insert(5,'Spain')
countries

# %% [markdown]
# #### Adding an element in a list

# %%
countries_2=['UK','Germany']
countries_3 = ['France','Italy']
eu = countries_2+countries_3+['Spain']
eu

# %% [markdown]
# #### Deleting an element in a list

# %%
countries.remove('Canada')
countries.pop(-2)
del countries[5]
countries

# %%
countries.sort()
countries
countries_2.sort(reverse=True)
countries_2

# %%
temp_0 = countries[:]
temp_1 = countries_3.copy()
temp_1, temp_0

# %% [markdown]
# #### Dictionary

# %%
# create a dictionary
squares = {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
squares
triple = {1: 9, 2: 18, 3: 21, 4: 24, 5: 75}
triple

# %%
triple.items()

# %%
triple.keys()

# %%
triple.values()

# %%
triple.update({6:84})
triple.update({7:95})
triple.update({8:104})
triple

# %% [markdown]
# #### Dictionary properties

# %%
copy_2 = triple.copy()
copy_2

# %%
new_dic = triple
new_dic

# %% [markdown]
# #### Removing elements

# %%
new_dic.pop(5)

# %%
new_dic

# %%
del new_dic[6]
new_dic

# %%
new_dic.clear()
new_dic

# %% [markdown]
# ***If statements***

# %%
age = 15
if age < 11:
    print('Primary')
elif 12 <= age <= 16:
    print('Secondaty!!')
else:
    print('Aún hay tiempo')

# %% [markdown]
# #### Looping

# %%
for i, c in enumerate(countries):
    print(i, c)

# %%
for k, v in triple.items():
    print(f'{k}: {v}')

# %% [markdown]
# ### Functions

# %%
def sm(a,b):
    return a + b

sm(12,45)

# %%
len(countries)

# %%
for i in range(11,18,2):
    print(i)

# %% [markdown]
# #### Modules

# %%
import os
os.getcwd()

# %%
os.listdir()

# %%
os.makedirs('Pandas')

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np

# %%
ar = np.array([[1,4],[5,6],[6,6]])
ar

# %%
df = pd.DataFrame(ar, index = ['a','b','c'],columns=['arg', 'bra'])
df

# %%
states = ['Cal','Tex','Flo','NY']
pop = [3961,2973,2194,1929]
dic_s = {'States':states,'Population':pop}

# %%
est = pd.DataFrame(dic_s)
est

# %%
url = 'https://raw.githubusercontent.com/ifrankandrade/python-course-for-excel-users/main/2.Intro%20to%20Pandas/StudentsPerformance.csv'
import requests
import io
s=requests.get(url).content

# %%
stu = pd.read_csv(io.StringIO(s.decode('utf-8')))
stu
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
stu.head(5)

# %%
stu.shape[0]
pd.set_option('display.max_rows',stu.shape[0])

# to displaly all values from the dataframa do not arun

# %%
stu.columns

# %%
stu.dtypes

# %%
round(stu.describe())

# %% [markdown]
# ### Functions

# %%
max(stu.index)

# %%
stu.gender

# %%
type(stu.gender)

# %%
stu[['gender', 'math score']]

# %%
stu['math score'].count()
stu['math score'].mean()
stu['math score'].std()

# %%
stu["ave"] = round((stu['math score'] + stu['reading score'])/2)

# %%
stu.gender.value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
stu['parental level of education'].value_counts(normalize=True)
# Out:
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: parental level of education, dtype: float64

# %%
stu.sort_values('math score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
stu.sort_values(['math score', 'reading score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
stu.sort_values(['math score', 'reading score'], ascending=False, inplace=True)

# %%
stu.sort_values(['race/ethnicity'], key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Pivot Tables

# %%
url = 'https://raw.githubusercontent.com/ifrankandrade/python-course-for-excel-users/main/3.Pivot%20Table/gdp.csv'

# %%
import requests
import io
s=requests.get(url).content

# %%
gdp = pd.read_csv(io.StringIO(s.decode('latin-1')))
gdp
# Out:
#       unid wbid      country  year        SES       gdppc  yrseduc  popshare
# 0        4  AFG  Afghanistan  1970   3.474212   709.00000      NaN  0.003097
# 1        4  AFG  Afghanistan  1920  26.968016   731.75677      NaN  0.003245
# 2        4  AFG  Afghanistan  1990   1.269530   604.00000      NaN  0.002347
# 3        4  AFG  Afghanistan  1960  15.763076   739.00000      NaN  0.003039
# 4        4  AFG  Afghanistan  2000   2.061114   565.00000      NaN  0.003309
# ...    ...  ...          ...   ...        ...         ...      ...       ...
# 2081   716  ZWE     Zimbabwe  1940  52.746567   813.00000      NaN  0.001113
# 2082   716  ZWE     Zimbabwe  2010  27.091389  1388.97300      NaN  0.002074
# 2083   716  ZWE     Zimbabwe  1990  59.110970  2526.07230      NaN  0.002039
# 2084   716  ZWE     Zimbabwe  1900  54.722645   601.00000      NaN  0.000996
# 2085   716  ZWE     Zimbabwe  1960  53.811077   938.00000      NaN  0.001268
#
# [2086 rows x 8 columns]

# %%
gdp.pivot(index='year', columns='country', values='gdppc')
# Out:
# country  Afghanistan     Albania      Algeria      Angola  Argentina  \
# year
# 1880       585.46509   522.00000    819.18604   533.66669   1731.500
# 1890       635.93024   598.00000    923.37207   567.33331   2152.000
# 1900       686.39532   685.00000   1027.55810   601.00000   2756.000
# 1910       736.86047   780.00000   1131.74410   628.69232   3822.000
# 1920       731.75677   861.31250   1201.21620   682.62964   3473.000
# 1930       702.83783   929.57141   1255.81080   747.81482   4080.000
# 1940       673.91895   965.28571   1310.40540   813.00000   4161.000
# 1950       645.00000  1001.00000   1365.00000  1052.00000   4987.000
# 1960       739.00000  1451.00000   2088.00000  1253.00000   5559.000
# 1970       709.00000  2004.00000   2249.00000  1768.00000   7302.000
# 1980       690.00000  2347.00000   3152.00000   961.00000   8206.000
# 1990       604.00000  4557.40820  10238.88400  4806.43020  10833.503
# ...

# %%
super = pd.read_excel('supermarket_sales.xlsx')
super
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
super.pivot_table(index='Gender', aggfunc='sum')
# Out:
#         Quantity  Rating    Tax 5%       Total  Unit price       cogs  \
# Gender
# Female      2869  3489.2  7994.425  167882.925    27687.24  159888.50
# Male        2641  3483.5  7384.944  155083.824    27984.89  147698.88
#
#         gross income  gross margin percentage
# Gender
# Female      7994.425              2385.714286
# Male        7384.944              2376.190476

# %%
super.pivot_table(index='Gender', values= ['Quantity', 'Total'], aggfunc='sum')
# Out:
#         Quantity       Total
# Gender
# Female      2869  167882.925
# Male        2641  155083.824

# %%
super.pivot_table(index='Gender', columns='Product line',
                  values= ['Quantity', 'Total'], aggfunc='sum')
# Out:
#                            Quantity                                         \
# Product line Electronic accessories Fashion accessories Food and beverages
# Gender
# Female                          488                 530                514
# Male                            483                 372                438
#
#                                                                      \
# Product line Health and beauty Home and lifestyle Sports and travel
# Gender
# Female                     343                498               496
# Male                       511                413               424
#
#                               Total                                         \
# Product line Electronic accessories Fashion accessories Food and beverages
# Gender
# Female                   27102.0225           30437.400         33170.9175
# Male                     27235.5090           23868.495         22973.9265
#
#
# ...

# %%
url = 'https://raw.githubusercontent.com/ifrankandrade/python-course-for-excel-users/main/4.Data%20Visualization/population_total.csv'

# %%
import requests
import io
s=requests.get(url).content

# %%
pop = pd.read_csv(io.StringIO(s.decode('latin-1')))
pop
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
pop.dropna(inplace=True)

# %%
pop =pop.pivot(index='year', columns='country', values='population')

# %%
spop = pop[['India','China','Russia', 'Brazil']]

# %%
spop
# Out:
# country         India         China       Russia       Brazil
# year
# 1955.0   4.098806e+08  6.122416e+08  111355300.0   62533919.0
# 1960.0   4.505477e+08  6.604081e+08  119871700.0   72179226.0
# 1965.0   4.991233e+08  7.242190e+08  126503736.0   83373530.0
# 1970.0   5.551898e+08  8.276014e+08  130148653.0   95113265.0
# 1975.0   6.231029e+08  9.262409e+08  133804858.0  107216205.0
# 1980.0   6.989528e+08  1.000089e+09  138053150.0  120694009.0
# 1985.0   7.843600e+08  1.075589e+09  142957284.0  135274080.0
# 1990.0   8.732778e+08  1.176884e+09  147531561.0  149003223.0
# 1995.0   9.639226e+08  1.240921e+09  148227466.0  162019896.0
# 2000.0   1.056576e+09  1.290551e+09  146404903.0  174790340.0
# 2005.0   1.147610e+09  1.330776e+09  143672116.0  186127103.0
# 2010.0   1.234281e+09  1.368811e+09  143479274.0  195713635.0
# 2015.0   1.310152e+09  1.406848e+09  144985057.0  204471769.0
# 2016.0   1.324517e+09  1.414049e+09  145275383.0  206163053.0
# ...

# %%
spop.plot(kind='line',xlabel='Year', ylabel='Pop', title='Population', figsize=(9,5)   )
# Out:
# <AxesSubplot:title={'center':'Population'}, xlabel='Year', ylabel='Pop'>

# %%
pop2 = spop[spop.index.isin([2020])]
pop2
# Out:
# country         India         China       Russia       Brazil
# year
# 2020.0   1.380004e+09  1.439324e+09  145934462.0  212559417.0

# %%
pop2 =pop2.T

# %%
pop2.plot(kind='bar',xlabel='Year', ylabel='Pop', title='Population', figsize=(9,5)   )
# Out:
# <AxesSubplot:title={'center':'Population'}, xlabel='Year', ylabel='Pop'>

# %%
pop2 = spop[spop.index.isin([1980,1990,2000,2010,2020])]
pop2
# Out:
# country         India         China       Russia       Brazil
# year
# 1980.0   6.989528e+08  1.000089e+09  138053150.0  120694009.0
# 1990.0   8.732778e+08  1.176884e+09  147531561.0  149003223.0
# 2000.0   1.056576e+09  1.290551e+09  146404903.0  174790340.0
# 2010.0   1.234281e+09  1.368811e+09  143479274.0  195713635.0
# 2020.0   1.380004e+09  1.439324e+09  145934462.0  212559417.0

# %%
pop2
# Out:
# year           1980.0        1990.0        2000.0        2010.0          2020
# country
# India    6.989528e+08  8.732778e+08  1.056576e+09  1.234281e+09  1.380004e+09
# China    1.000089e+09  1.176884e+09  1.290551e+09  1.368811e+09  1.439324e+09
# Russia   1.380532e+08  1.475316e+08  1.464049e+08  1.434793e+08  1.459345e+08
# Brazil   1.206940e+08  1.490032e+08  1.747903e+08  1.957136e+08  2.125594e+08

# %%
pop2.plot(kind='bar',xlabel='Year', ylabel='Pop', title='Population', figsize=(9,5)   )
# Out:
# <AxesSubplot:title={'center':'Population'}, xlabel='Year', ylabel='Pop'>

# %%
pop2
pop20 = pop2['2020']

# %%
pop20.plot(kind='pie',xlabel='Year', ylabel='Pop', title='Population', figsize=(9,5),subplots=True   )
# Out:
# array([<AxesSubplot:ylabel='Pop'>], dtype=object)
